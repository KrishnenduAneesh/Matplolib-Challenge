# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
combined_data = pd.merge(study_results, mouse_metadata, on='Mouse ID', how='left')

# Display the data table for preview
combined_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
number_mice=len(mouse_metadata['Mouse ID'])
number_mice
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice = study_results[study_results.duplicated(subset=['Mouse ID', 'Timepoint'], keep=False)]
duplicate_mice_ids = duplicate_mice['Mouse ID'].unique()
duplicate_mice_ids
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_data=combined_data.loc[combined_data['Mouse ID']== "g989"]
duplicate_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_combined_data = combined_data.drop_duplicates(subset='Mouse ID')
clean_combined_data
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       b128          0                45.0                 0    Capomulin
# 1       f932          0                45.0                 0     Ketapril
# 2       g107          0                45.0                 0     Ketapril
# 3       a457          0                45.0                 0     Ketapril
# 4       c819          0                45.0                 0     Ketapril
# ..       ...        ...                 ...               ...          ...
# 245     t565          0                45.0                 0    Capomulin
# 246     i557          0                45.0                 0    Capomulin
# 247     m957          0                45.0                 0    Capomulin
# 248     f966          0                45.0                 0    Capomulin
# 249     m601          0                45.0                 0    Capomulin
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
number_of_mice= len(clean_combined_data['Mouse ID'])-1
number_of_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
grouped_data = combined_data.groupby('Drug Regimen')['Tumor Volume (mm3)']


mean_tumor_volume = grouped_data.mean()
median_tumor_volume = grouped_data.median()
variance_tumor_volume = grouped_data.var()
std_dev_tumor_volume = grouped_data.std()
std_err_tumor_volume = grouped_data.sem()

statistics_per_regimen = pd.DataFrame({
    'Mean Tumor Volume': mean_tumor_volume,
    'Median Tumor Volume': median_tumor_volume,
    'Tumor Volume Variance': variance_tumor_volume,
    'Tumor Volume Std. Dev.': std_dev_tumor_volume,
    'Tumor Volume Std. Err.': std_err_tumor_volume
})

print(statistics_per_regimen)
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
grouped_data = combined_data.groupby('Drug Regimen')['Tumor Volume (mm3)']

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
mean_tumor_volume = grouped_data.mean()
median_tumor_volume = grouped_data.median()
variance_tumor_volume = grouped_data.var()
std_dev_tumor_volume = grouped_data.std()
std_err_tumor_volume = grouped_data.sem()

statistics_per_regimen = pd.DataFrame({
    'Mean Tumor Volume': mean_tumor_volume,
    'Median Tumor Volume': median_tumor_volume,
    'Tumor Volume Variance': variance_tumor_volume,
    'Tumor Volume Std. Dev.': std_dev_tumor_volume,
    'Tumor Volume Std. Err.': std_err_tumor_volume
})

print(statistics_per_regimen)
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
grouped_data = combined_data.groupby('Drug Regimen')['Tumor Volume (mm3)']
summary_statistics = grouped_data.agg([
    'mean', 'median', 'var', 'std', 'sem'
])
summary_statistics.columns = ['mean', 'median', 'var', 'std', 'sem']

print(summary_statistics)
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)
# Using the aggregation method, produce the same summary statistics in a single line

grouped_data = combined_data.groupby('Drug Regimen')['Tumor Volume (mm3)']
summary_statistics = grouped_data.agg([
    'mean', 'median', 'var', 'std', 'sem'
])
summary_statistics.columns = ['mean', 'median', 'var', 'std', 'sem']

print(summary_statistics)
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
counts_per_regimen = combined_data['Drug Regimen'].value_counts()

# Plotting the bar chart using Pandas
counts_per_regimen.plot(kind='bar', color='blue', figsize=(8, 6))
plt.xlabel('Drug Regimen')
plt.ylabel('# of Mouse ID/Timepoints')
plt.xticks(rotation=0)  # Rotating x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
counts_per_regimen = combined_data['Drug Regimen'].value_counts()

# Plotting the bar plot using Matplotlib
plt.figure(figsize=(8, 6))
plt.bar(counts_per_regimen.index, counts_per_regimen.values, color='blue')
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')
plt.xticks(rotation=90)  # Rotating x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
gender_distribution = combined_data['Sex'].value_counts()

# Plotting the pie plot using Pandas
gender_distribution.plot(kind='pie', autopct=lambda p: '{:.1f}%'.format(round(p)), startangle=0, colors=['blue', 'orange'])
#plt.title('Distribution of Female vs Male Mice')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
gender_distribution = combined_data['Sex'].value_counts()

# Plotting the pie chart using Matplotlib's pyplot
plt.figure(figsize=(5, 5))
plt.pie(gender_distribution, labels=gender_distribution.index, autopct=lambda p: '{:.1f}%'.format(round(p)), startangle=0, colors=['blue', 'orange'])
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
specified_regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Filter for the specified treatment regimens
filtered_data = combined_data[combined_data['Drug Regimen'].isin(specified_regimens)]

# Find the last (greatest) timepoint for each mouse
max_timepoints = filtered_data.groupby(['Mouse ID'])['Timepoint'].max().reset_index()

# Merge to get the tumor volume at the last timepoint for the specified regimens
final_tumor_volume = pd.merge(max_timepoints, filtered_data, on=['Mouse ID', 'Timepoint'], how='inner')

# Display the final tumor volume of each mouse in the specified treatment regimens
print(final_tumor_volume[['Drug Regimen', 'Mouse ID', 'Tumor Volume (mm3)']])
# Out:
#    Drug Regimen Mouse ID  Tumor Volume (mm3)
# 0     Infubinol     a203           67.973419
# 1     Infubinol     a251           65.525743
# 2      Ceftamin     a275           62.999356
# 3      Ramicane     a411           38.407618
# 4      Ramicane     a444           43.047543
# ..          ...      ...                 ...
# 95     Ceftamin     y769           68.594745
# 96    Capomulin     y793           31.896238
# 97     Ceftamin     y865           64.729837
# 98     Ramicane     z578           30.638696
# 99    Infubinol     z581           62.754451
#
# [100 rows x 3 columns]

# %%
#Put treatments into a list for for loop (and later for plot labels)
# List of treatments for the loop and plot labels
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create an empty list to store tumor volume data
tumor_vol_data = []

#Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
# Locate the rows which contain mice on each drug and get the tumor volumes

for treatment in treatments:
    # Filter the data for each treatment
    treatment_data = combined_data[combined_data['Drug Regimen'] == treatment]
    
    # Get the tumor volumes for this treatment
    tumor_volumes = treatment_data['Tumor Volume (mm3)']
    
    # Add subset data to the list
    tumor_vol_data.append(tumor_volumes)
    
    #Calculate the IQR and determine potential outliers
    quartiles = tumor_volumes.quantile([0.25, 0.5, 0.75])
    lower_q = quartiles[0.25]
    upper_q = quartiles[0.75]
    iqr = upper_q - lower_q
    lower_bound = lower_q - (1.5 * iqr)
    upper_bound = upper_q + (1.5 * iqr)
    
    # Determine outliers using upper and lower bounds
    outliers = tumor_volumes[(tumor_volumes < lower_bound) | (tumor_volumes > upper_bound)]
    
    # Print results
    #print(f"-----{treatment} Treatment-----")
    print(f"{treatment} Potential outliers for : {outliers}\n")
    print(f"IQR for {treatment}: {iqr}")
    
    #print(f"Values below {lower_bound} could be outliers.")
    #print(f"Values above {upper_bound} could be outliers.")
# Out:
# Capomulin Potential outliers for : 1652    25.472143
# 1849    23.343598
# Name: Tumor Volume (mm3), dtype: float64
#
# IQR for Capomulin: 7.314067135000002
# Ramicane Potential outliers for : 1814    22.050126
# Name: Tumor Volume (mm3), dtype: float64
#
# IQR for Ramicane: 8.325365415
# Infubinol Potential outliers for : Series([], Name: Tumor Volume (mm3), dtype: float64)
#
# IQR for Infubinol: 10.002090667500006
# Ceftamin Potential outliers for : Series([], Name: Tumor Volume (mm3), dtype: float64)
#
# IQR for Ceftamin: 9.593010457500007

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.figure(figsize=(8, 6))
plt.boxplot(tumor_vol_data, labels=treatments)
plt.ylabel('Final Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
mouse_id = 'y793'  

# Filter data for the selected mouse treated with Capomulin
mouse_data = combined_data[(combined_data['Mouse ID'] == mouse_id) & (combined_data['Drug Regimen'] == 'Capomulin')]

# Plot tumor volume vs. time point for the selected mouse
plt.figure(figsize=(8, 6))
plt.plot(mouse_data['Timepoint'], mouse_data['Tumor Volume (mm3)'], marker='o', color='blue')
plt.title(f'Capomulin treatment of mouse {mouse_id}')
plt.xlabel('Timepoint (Days)')
plt.ylabel('Tumor Volume (mm3)')
plt.grid(True)
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
capomulin_data = combined_data[combined_data['Drug Regimen'] == 'Capomulin']

# Calculate the average tumor volume for each mouse
average_tumor_volume = capomulin_data.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()

# Merge average tumor volume with the original Capomulin data to include weight
capomulin_with_avg_volume = capomulin_data.merge(average_tumor_volume, on='Mouse ID', suffixes=['', '_avg'])

# Remove duplicate Mouse ID entries and keep only unique records
unique_capomulin_data = capomulin_with_avg_volume.drop_duplicates(subset='Mouse ID')

# Create a scatter plot of mouse weight vs. the average observed tumor volume
plt.figure(figsize=(8, 6))
plt.scatter(unique_capomulin_data['Weight (g)'], unique_capomulin_data['Tumor Volume (mm3)_avg'], color='blue')
plt.title('Mouse Weight vs. Average Tumor Volume (Capomulin)')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

import seaborn as sns
from scipy import stats
correlation_coefficient = st.pearsonr(unique_capomulin_data['Weight (g)'], unique_capomulin_data['Tumor Volume (mm3)_avg'])[0]

# Create a linear regression model and plot
print(f"The correlation between mouse weight and the average tumor volume is  {correlation_coefficient}")
plt.figure(figsize=(8, 6))
sns.regplot(x='Weight (g)', y='Tumor Volume (mm3)_avg', data=unique_capomulin_data, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.grid(True)
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is  0.8419363424694721
